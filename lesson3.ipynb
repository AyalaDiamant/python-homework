# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = {'שם': ['אליז', 'בת שבע', 'גליה'],
        'כיתה': ['יג7', 'יד7', 'יב3'],
        'ממוצע ציונים': [89,55,96]}

# %%
sample = pd.DataFrame(data)
sample
# Out:
#        שם כיתה  ממוצע ציונים
# 0    אליז  יג7            89
# 1  בת שבע  יד7            55
# 2    גליה  יב3            96

# %%
data.add{['מיכל']}
# Out:
#   Cell In[11], line 1
#     data.add{['מיכל']}
#             ^
# SyntaxError: invalid syntax

# %%
new_row= {'שם' : 'אילה', 'כיתה': 'יב4', 'ממוצע ציונים':78}

# %%
new_row
# Out:
# {'שם': 'אילה', 'כיתה': 'יב4', 'ממוצע ציונים': 78}

# %%
data.insert[len(pd)] = new_row
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 data.insert[len(pd)] = new_row
#
# AttributeError: 'dict' object has no attribute 'insert'

# %%
sample.insert(new_row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sample.insert(new_row)
#
# TypeError: DataFrame.insert() missing 2 required positional arguments: 'column' and 'value'

# %%
sample.loc[len(sample)] = new_row

# %%
sample
# Out:
#        שם כיתה  ממוצע ציונים
# 0    אליז  יג7            89
# 1  בת שבע  יד7            55
# 2    גליה  יב3            96
# 3    אילה  יב4            78

# %%
type(sample.iloc[1])
# Out:
# pandas.core.series.Series

# %%
sample['שם']
# Out:
# 0      אליז
# 1    בת שבע
# 2      גליה
# 3      אילה
# Name: שם, dtype: object

# %%
sample[sample['כיתה'] == 'יד7']
# Out:
#        שם כיתה  ממוצע ציונים
# 1  בת שבע  יד7            55

# %%
sample
# Out:
#        שם כיתה  ממוצע ציונים
# 0    אליז  יג7            89
# 1  בת שבע  יד7            55
# 2    גליה  יב3            96
# 3    אילה  יב4            78

# %%
sample['ממוצע ציונים '].max()

# %%
df = pd.read_csv('cities.csv')

# %%
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df = pd.Series()
df.is_unique
# Out:
# True

# %%
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df['LatD'].mean()
# Out:
# 38.8203125

# %%
df['LatD'].min()
# Out:
# 26

# %%
df['LatD'].max()
# Out:
# 50

# %%
df.insert(3, 'avg', {LatD/LatD})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df.insert(3, 'avg', {LatD/LatD})
#
# NameError: name 'LatD' is not defined

# %%
df.rename(columns={'Unnamed: 0': 'model'}, inplace=True)

# %%
# Out:
#      LatD   "LatM"   "LatS"   avg  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59  True   "N"       80       39        0   "W"
# 1      42       52       48  True   "N"       97       23       23   "W"
# 2      46       35       59  True   "N"      120       30       36   "W"
# 3      42       16       12  True   "N"       71       48        0   "W"
# 4      43       37       48  True   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...   ...      ...      ...      ...   ...
# 123    39       31       12  True   "N"      119       48       35   "W"
# 124    50       25       11  True   "N"      104       39        0   "W"
# 125    40       10       48  True   "N"      122       14       23   "W"
# 126    40       19       48  True   "N"       75       55       48   "W"
# 127    41        9       35  True   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# ...

# %%
df
# Out:
#      LatD   "LatM"   "LatS"   avg  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59  True   "N"       80       39        0   "W"
# 1      42       52       48  True   "N"       97       23       23   "W"
# 2      46       35       59  True   "N"      120       30       36   "W"
# 3      42       16       12  True   "N"       71       48        0   "W"
# 4      43       37       48  True   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...   ...      ...      ...      ...   ...
# 123    39       31       12  True   "N"      119       48       35   "W"
# 124    50       25       11  True   "N"      104       39        0   "W"
# 125    40       10       48  True   "N"      122       14       23   "W"
# 126    40       19       48  True   "N"       75       55       48   "W"
# 127    41        9       35  True   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# ...
