# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.1-cp310-cp310-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.1-cp310-cp310-win_amd64.whl (11.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('cities.csv')

# %%
df
# Out:
#      LatD   "LatM"  LatS  avg    NS  LonD   LonM""   "LonS"    EW  \
# 0      41        5    59    1   "N"    80       39        0   "W"
# 1      42       52    48    1   "N"    97       23       23   "W"
# 2      46       35    59    1   "N"   120       30       36   "W"
# 3      42       16    12    1   "N"    71       48        0   "W"
# 4      43       37    48    1   "N"    89       46       11   "W"
# ..    ...      ...   ...  ...   ...   ...      ...      ...   ...
# 123    39       31    12    1   "N"   119       48       35   "W"
# 124    50       25    11    1   "N"   104       39        0   "W"
# 125    40       10    48    1   "N"   122       14       23   "W"
# 126    40       19    48    1   "N"    75       55       48   "W"
# 127    41        9    35    1   "N"    81       14       23   "W"
#
#                    City  State
# 0          "Youngstown"     OH
# 1             "Yankton"     SD
# 2              "Yakima"     WA
# 3           "Worcester"     MA
# ...

# %%
df['ratio'] = df["LatD"]/df["LatS"]

# %%
df
# Out:
#      LatD   "LatM"  LatS  avg    NS  LonD   LonM""   "LonS"    EW  \
# 0      41        5    59    1   "N"    80       39        0   "W"
# 1      42       52    48    1   "N"    97       23       23   "W"
# 2      46       35    59    1   "N"   120       30       36   "W"
# 3      42       16    12    1   "N"    71       48        0   "W"
# 4      43       37    48    1   "N"    89       46       11   "W"
# ..    ...      ...   ...  ...   ...   ...      ...      ...   ...
# 123    39       31    12    1   "N"   119       48       35   "W"
# 124    50       25    11    1   "N"   104       39        0   "W"
# 125    40       10    48    1   "N"   122       14       23   "W"
# 126    40       19    48    1   "N"    75       55       48   "W"
# 127    41        9    35    1   "N"    81       14       23   "W"
#
#                    City  State     ratio
# 0          "Youngstown"     OH  0.694915
# 1             "Yankton"     SD  0.875000
# 2              "Yakima"     WA  0.779661
# ...

# %%
rslt_df = df[df['City'] == '"Vancouver"	']
rslt_df
# Out:
# Empty DataFrame
# Columns: [LatD,  "LatM", LatS, avg, NS, LonD,  LonM"",  "LonS",  EW, City,  State, ratio]
# Index: []

# %%
df
# Out:
#      LatD   "LatM"  LatS  avg    NS  LonD   LonM""   "LonS"    EW  \
# 0      41        5    59    1   "N"    80       39        0   "W"
# 1      42       52    48    1   "N"    97       23       23   "W"
# 2      46       35    59    1   "N"   120       30       36   "W"
# 3      42       16    12    1   "N"    71       48        0   "W"
# 4      43       37    48    1   "N"    89       46       11   "W"
# ..    ...      ...   ...  ...   ...   ...      ...      ...   ...
# 123    39       31    12    1   "N"   119       48       35   "W"
# 124    50       25    11    1   "N"   104       39        0   "W"
# 125    40       10    48    1   "N"   122       14       23   "W"
# 126    40       19    48    1   "N"    75       55       48   "W"
# 127    41        9    35    1   "N"    81       14       23   "W"
#
#                    City  State     ratio
# 0          "Youngstown"     OH  0.694915
# 1             "Yankton"     SD  0.875000
# 2              "Yakima"     WA  0.779661
# ...

# %%
df_citys = df['City']
sorted_df = df_citys.sort_values()

# %%
df
# Out:
#      LatD   "LatM"  LatS  avg    NS  LonD   LonM""   "LonS"    EW  \
# 0      41        5    59    1   "N"    80       39        0   "W"
# 1      42       52    48    1   "N"    97       23       23   "W"
# 2      46       35    59    1   "N"   120       30       36   "W"
# 3      42       16    12    1   "N"    71       48        0   "W"
# 4      43       37    48    1   "N"    89       46       11   "W"
# ..    ...      ...   ...  ...   ...   ...      ...      ...   ...
# 123    39       31    12    1   "N"   119       48       35   "W"
# 124    50       25    11    1   "N"   104       39        0   "W"
# 125    40       10    48    1   "N"   122       14       23   "W"
# 126    40       19    48    1   "N"    75       55       48   "W"
# 127    41        9    35    1   "N"    81       14       23   "W"
#
#                    City  State     ratio
# 0          "Youngstown"     OH  0.694915
# 1             "Yankton"     SD  0.875000
# 2              "Yakima"     WA  0.779661
# ...

# %%
sorted_df
# Out:
# 127        "Ravenna"
# 126        "Reading"
# 125      "Red Bluff"
# 124         "Regina"
# 123           "Reno"
#            ...
# 3        "Worcester"
# 2           "Yakima"
# 1          "Yankton"
# 0       "Youngstown"
# 11              null
# Name: City, Length: 128, dtype: object
